# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishardmunene/Multimodal-Image-to-Text/blob/main/Multi_modal_Test_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required modules
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Install required packages
# !pip install torch transformers diffusers pillow pyyaml numpy pycocotools

# Install specific packages for caption generation
# !pip install transformers[sentencepiece]

# Create project directory if it doesn't exist
# !mkdir -p /content/project/Multimodal-Image-to-Text
# Navigate to project directory
# %cd /content/project/Multimodal-Image-to-Text

# Create necessary directories
# !mkdir -p data/images data/annotations

# Download COCO annotations (both train and val)
print("Downloading COCO annotations...")
# !wget -q -P data/ http://images.cocodataset.org/annotations/annotations_trainval2017.zip
print("Extracting COCO annotations...")
# !unzip -q data/annotations_trainval2017.zip -d data/

# Download validation images (smaller dataset for testing)
print("Downloading COCO validation images...")
# !wget -q -P data/ http://images.cocodataset.org/zips/val2017.zip
print("Extracting validation images...")
# !unzip -q data/val2017.zip -d data/images/

# Move annotations to correct location if needed
# !mv data/annotations/* data/
# !rm -rf data/annotations  # Remove empty directory
# !mkdir -p data/annotations
# !mv data/captions_train2017.json data/annotations/
# !mv data/captions_val2017.json data/annotations/

# Clean up zip files
# !rm -f data/*.zip
# !rm -f data/annotations_trainval2017.zip

# Verify the setup
print("\nVerifying setup...")
print("Annotations files:")
# !ls -l data/annotations/
print("\nImage files:")
# !ls -l data/images/ | head -n 5

# Verify specific files exist
if not os.path.exists('data/annotations/captions_train2017.json'):
    print("ERROR: Training annotations file is missing!")
if not os.path.exists('data/annotations/captions_val2017.json'):
    print("ERROR: Validation annotations file is missing!")
if not os.path.exists('data/images/val2017'):
    print("ERROR: Validation images directory is missing!")

print("\nSetup complete!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.31.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.5.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.17.0)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (4.67.1)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (4.25.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers[sentencepiece]) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers[sentencepiece]) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2024.12.14)
# /content/project/Multimodal-Image-to-Text
# Downloading COCO annotations...
# Extracting COCO annotations...
# replace data/annotations/captions_train2017.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace data/annotations/captions_val2017.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# Downloading COCO validation images...
# Extracting validation images...
# replace data/images/val2017/000000212226.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#
# Verifying setup...
# Annotations files:
# total 93500
# -rw-rw-r-- 1 root root 91865115 Sep  1  2017 captions_train2017.json
# -rw-rw-r-- 1 root root  3872473 Sep  1  2017 captions_val2017.json
#
# Image files:
# total 1500
# -rw-r--r-- 1 root root  77539 Jan 15 18:31 000000006818.jpg
# -rw-r--r-- 1 root root  40833 Jan 15 18:31 000000037777.jpg
# -rw-r--r-- 1 root root 183303 Jan 15 18:31 000000087038.jpg
# -rw-r--r-- 1 root root 207538 Jan 15 18:31 000000174482.jpg
#
# Setup complete!

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install required packages
# !pip install torch transformers diffusers pillow pyyaml numpy

# Navigate to your Drive directory where the zip file is located
# Assuming the zip file is in the root of your Google Drive
# %cd /content/drive/MyDrive

# Unzip the project
# !unzip -o "Multimodal-Image-to-Text.zip" -d "/content/project"

# Navigate to the project directory
# %cd /content/project/Multimodal-Image-to-Text

# Verify the contents of the directory
# !ls

# Run the main script
# !python main.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.31.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# /content/drive/MyDrive
# Archive:  Multimodal-Image-to-Text.zip
#   inflating: /content/project/Multimodal-Image-to-Text/requirements.txt
#   inflating: /content/project/Multimodal-Image-to-Text/README.md
#   inflating: /content/project/Multimodal-Image-to-Text/.gitignore
#   inflating: /content/project/Multimodal-Image-to-Text/project_structure
#   inflating: /content/project/Multimodal-Image-to-Text/main.py
#   inflating: /content/project/Multimodal-Image-to-Text/colab_setup.py
#   inflating: /content/project/Multimodal-Image-to-Text/config/config.yaml
#   inflating: /content/project/Multimodal-Image-to-Text/.git/config
#   inflating: /content/project/Multimodal-Image-to-Text/.git/HEAD
#   inflating: /content/project/Multimodal-Image-to-Text/.git/description
#   inflating: /content/project/Multimodal-Image-to-Text/.git/index
#   inflating: /content/project/Multimodal-Image-to-Text/.git/packed-refs
#   inflating: /content/project/Multimodal-Image-to-Text/.git/COMMIT_EDITMSG
#   inflating: /content/project/Multimodal-Image-to-Text/.git/FETCH_HEAD
#    creating: /content/project/Multimodal-Image-to-Text/.git/objects/9d/
#    creating: /content/project/Multimodal-Image-to-Text/.git/objects/2a/
#    creating: /content/project/Multimodal-Image-to-Text/.git/objects/e1/
#   inflating: /content/project/Multimodal-Image-to-Text/.git/info/exclude
#   inflating: /content/project/Multimodal-Image-to-Text/.git/logs/HEAD
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/commit-msg.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/pre-rebase.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/pre-commit.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/applypatch-msg.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/pre-receive.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/prepare-commit-msg.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/post-update.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/pre-merge-commit.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/pre-applypatch.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/pre-push.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/update.sample
#   inflating: /content/project/Multimodal-Image-to-Text/.git/hooks/push-to-checkout.sample
#   inflating: /content/project/Multimodal-Image-to-Text/src/pipeline/caption_pipeline.py
#   inflating: /content/project/Multimodal-Image-to-Text/src/utils/text_processing.py
#   inflating: /content/project/Multimodal-Image-to-Text/src/utils/image_processing.py
#   inflating: /content/project/Multimodal-Image-to-Text/src/models/sdxl_wrapper.py
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/92/8ed60f7c935d792c97508e2f44fb9e7c3da30c
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/68/82845c6a94918ce1803d9892b31cecd2cf414d
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/67/d6c97f4f0bacf04bb1544f0d55244ec5e382ce
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/93/a156a2c6dbafd4124eb27de427242915db38ba
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/34/d07ced3d394552fb7895bbed7896d16c976b08
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/33/97eb88c829446b6a7aecc3cfdb9036c79388e8
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/9d/8c3885e5696f8dcebc187ccfd57ff2bf4c7dcb
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/bd/045f205a18c951d060c80ed1de43a927dce418
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/bc/0d42b3b28c4cb0e625ac358c28b358ce67860f
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/fc/a4d9f988e35b10eac945285cd2f3f610e4c319
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/fb/98ceac8b828e3e6cef282d2bff6317c2ab233e
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/ed/725bf84249dfe2ebffc79f8d0c2ae25dafa270
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/20/6e327c66b905faa1b3b434b8b6a333960e7f38
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/4b/c002b786ee2fb5b417a3a43505b06e16171ede
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/pack/pack-14b3c6889af0b9ebb913cf720ee1868118a57cfe.pack
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects/pack/pack-14b3c6889af0b9ebb913cf720ee1868118a57cfe.idx
#   inflating: /content/project/Multimodal-Image-to-Text/.git/objects
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Successfully loaded COCO annotations
# Processing image: 000000397133.jpg
# Ground truth captions:
# - A man is in a kitchen making pizzas.
# - Man in apron standing on front of oven with pans and bakeware
# - A baker is working in the kitchen rolling dough.
# - A person standing by a stove in a kitchen.
# - A table with pies being made and a person standing near a wall with pots and pans hanging on the wall.
# Generated caption: a woman in a kitchen
#
# Processing image: 000000037777.jpg
# Ground truth captions:
# - The dining table near the kitchen has a bowl of fruit on it.
# - A small kitchen has various appliances and a table.
# - The kitchen is clean and ready for us to see.
# - A kitchen and dining area decorated in white.
# - A kitchen that has a bowl of fruit on the table.
# Generated caption: a kitchen with a table and chairs in it
#
# Processing image: 000000252219.jpg
# Ground truth captions:
# - a person with a shopping cart on a city street
# - City dwellers walk by as a homeless man begs for cash.
# - People walking past a homeless man begging on a city street
# - a homeless man holding a cup and standing next to a shopping cart on a street
# - People are walking on the street by a homeless person.
# Generated caption: a woman walking down the street
#
# Processing image: 000000087038.jpg
# Ground truth captions:
# - A person on a skateboard and bike at a skate park.
# - A man on a skateboard performs a trick at the skate park
# - A skateboarder jumps into the air as he performs a skateboard trick.
# - Athletes performing tricks on a BMX bicycle and a skateboard.
# - a man falls off his skateboard in a skate park.
# Generated caption: a skate park
#
# Processing image: 000000174482.jpg
# Ground truth captions:
# - a blue bike parked on a side walk
# - A bicycle is chained to a fixture on a city street
# - A blue bicycle sits on a sidewalk near a street.
# - A bicycle is locked up to a post
# - a bike sits parked next to a street
# Generated caption: a bike parked on the sidewalk
#
# Processing image: 000000403385.jpg
# Ground truth captions:
# - A bathroom that has a broken wall in the shower.
# - A bathroom looks clean but is missing tile at the shower stall.
# - A view of a bathroom that needs to be fixed up.
# - a shower toilet and sink in a basement bathroom
# - A very big whit rest room with a shabby looking shower.
# Generated caption: a bathroom with a toilet, sink, and shower
#
# Processing image: 000000006818.jpg
# Ground truth captions:
# - a couple of buckets in a white room
# - A bathroom with no toilets and a red and green bucket.
# - a shower room with two buckets, tolet paper holder and soap.
# - A standing toilet in a bathroom next to a window.
# - This picture looks like a janitors closet with buckets on the floor.
# Generated caption: a bathroom with a toilet and a bucket
#
# Processing image: 000000480985.jpg
# Ground truth captions:
# - The shiny motorcycle has been put on display.
# - The new motorcycle on display is very shiny.
# - A motorcycle is parked inside of a building.
# - A brand new motorcycle on display at a show.
# - The front end of a red motorcycle that is on display.
# Generated caption: a motorcycle on display
#
# Processing image: 000000458054.jpg
# Ground truth captions:
# - A row of white toilets sitting on top of a dirt ground.
# - A bunch of dirty looking white toilets in a row outside.
# - There is a row of used and broken toilets in a field.
# - A row of toilets with broken seat tops on the ground.
# - LOTS OF BROKEN TOILETS SITTING OUT ON A LAWN
# Generated caption: a bunch of toilets
#
# Processing image: 000000331352.jpg
# Ground truth captions:
# - A small closed toilet in a cramped space.
# - A tan toilet and sink combination in a small room.
# - This is an advanced toilet with a sink and control panel.
# - A close-up picture of a toilet with a fountain.
# - Off white toilet with a faucet and controls.
# Generated caption: a toilet with a tank and a tankless toilet
